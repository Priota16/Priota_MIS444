# %% [markdown]
# <a href="https://colab.research.google.com/github/Priota16/Priota_MIS444/blob/main/MIS444_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile

with zipfile.ZipFile("zipfile", "r") as z:
    z.extractall("f1data")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
races = pd.read_csv("f1data/races.csv")
results = pd.read_csv("f1data/results.csv")
drivers = pd.read_csv("f1data/drivers.csv")
constructors = pd.read_csv("f1data/constructors.csv")
circuits = pd.read_csv("f1data/circuits.csv")
qualifying = pd.read_csv("f1data/qualifying.csv")
pit_stops = pd.read_csv("f1data/pit_stops.csv")

# %%
df = results.merge(races.rename(columns={'url': 'url_race'}), on="raceId", how="left")
df = df.merge(circuits.rename(columns={'url': 'url_circuit'}), on="circuitId", how="left")
df = df.merge(drivers.rename(columns={'url': 'url_driver'}), on="driverId", how="left")
df = df.merge(constructors.rename(columns={'url': 'url_constructor'}), on="constructorId", how="left")
df = df.merge(qualifying, on=["raceId", "driverId"], how="left")
df = df.merge(pit_stops, on=["raceId", "driverId"], how="left")
